# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0,2*np.pi,20)
y = np.sin(x)

plt.figure()
plt.plot(x,y,'b--')

# %%
import numpy as np
import pandas as pd

m = pd.read_excel('C:\\Users\\Carolina\\Desktop\\python\\ejemplo.xlsx')
m.loc[5]=['Luigi', 5, 4, 2, 3, 4]

n1=m['NOTA_1'].values
n2=m['NOTA_2'].values
n3=m['NOTA_3'].values
n4=m['NOTA_4'].values
n5=m['NOTA_5'].values


nf =(n1+n2+n3+n4+n5)/5
m.insert(6, 'NOTA_FINAL', nf)

print(nf)
print(m)
# Out:
# [3.3  3.1  3.42 3.46 2.58 3.6 ]
#      NOMBRE  NOTA_1  NOTA_2  NOTA_3  NOTA_4  NOTA_5  NOTA_FINAL
# 0     Luisa     3.0     3.4     4.5     2.4     3.2        3.30
# 1     Laura     2.4     4.2     1.2     3.2     4.5        3.10
# 2   Natalia     5.0     0.9     3.7     2.5     5.0        3.42
# 3  Sebatian     3.2     2.3     4.1     3.4     4.3        3.46
# 4    Manuel     2.1     1.2     4.8     4.5     0.3        2.58
# 5     Luigi     5.0     4.0     2.0     3.0     4.0        3.60
